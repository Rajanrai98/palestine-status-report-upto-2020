# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\Israel-Palestine.1.csv")

# %%
data
# Out:
#     Year    Country         GDP_USD Population  growth_rate  fertility_rate  \
# 0   2000     Israel  132.02 billion  60,49,000         5.18            2.89
# 1   2000  Palestine    4.56 billion  33,74,000         5.33            5.36
# 2   2001     Israel  131.02 billion  61,65,000        -0.47            2.89
# 3   2001  Palestine    4.59 billion  34,00,000       -50.00            5.22
# 4   2002     Israel  126.64 billion  62,63,000        -0.35            2.98
# 5   2002  Palestine    4.34 billion  34,21,000       -46.30            5.07
# 6   2003     Israel  129.56 billion  66,84,000         2.80            2.81
# 7   2003  Palestine    3.56 billion  36,93,000       -16.10            5.15
# 8   2004     Israel  143.53 billion  68,30,000         4.50            2.84
# 9   2004  Palestine    3.89 billion  37,91,000        10.50            4.95
# 10  2005     Israel  155.05 billion  69,25,000         4.97            2.87
# ...

# %%
data = data[data['Country']=='Palestine']

# %%
data
# Out:
#     Year    Country        GDP_USD Population  growth_rate  fertility_rate  \
# 1   2000  Palestine   4.56 billion  33,74,000         5.33            5.36
# 3   2001  Palestine   4.59 billion  34,00,000       -50.00            5.22
# 5   2002  Palestine   4.34 billion  34,21,000       -46.30            5.07
# 7   2003  Palestine   3.56 billion  36,93,000       -16.10            5.15
# 9   2004  Palestine   3.89 billion  37,91,000        10.50            4.95
# 11  2005  Palestine   4.13 billion  38,90,000         7.60            4.78
# 13  2006  Palestine   4.47 billion  37,62,000         5.80            4.14
# 15  2007  Palestine   4.96 billion  38,65,000         5.30            4.07
# 17  2008  Palestine   5.05 billion  39,66,000         4.20            3.98
# 19  2009  Palestine   4.98 billion  40,18,000         6.80            4.00
# 21  2010  Palestine   4.95 billion  40,70,000         8.50            3.99
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Country', 'GDP_USD', 'Population', 'growth_rate',
#        'fertility_rate', 'Infant Mortality Rate (per 1,000 live births)',
#        'Maternal Mortality Rate (per 100,000 live births)',
#        'agricultural_output', 'Active Military Personnel',
#        'Reserve Military Personnel', 'literacy_rate', 'IT_output',
#        'Number of Tanks', 'Number of Submarines',
#        'Number of Armoured Vehicles'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 43
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Year                                               22 non-null     int64
#  1   Country                                            22 non-null     object
#  2   GDP_USD                                            22 non-null     object
#  3   Population                                         22 non-null     object
#  4   growth_rate                                        22 non-null     float64
#  5   fertility_rate                                     22 non-null     float64
#  6   Infant Mortality Rate (per 1,000 live births)      22 non-null     float64
#  7   Maternal Mortality Rate (per 100,000 live births)  22 non-null     float64
# ...

# %%
data.isnull().sum()
# Out:
# Year                                                  0
# Country                                               0
# GDP_USD                                               0
# Population                                            0
# growth_rate                                           0
# fertility_rate                                        0
# Infant Mortality Rate (per 1,000 live births)         0
# Maternal Mortality Rate (per 100,000 live births)     0
# agricultural_output                                   0
# Active Military Personnel                            22
# Reserve Military Personnel                           22
# literacy_rate                                        13
# IT_output                                            13
# Number of Tanks                                      22
# Number of Submarines                                 22
# Number of Armoured Vehicles                          22
# dtype: int64

# %%
data = data.fillna(0)

# %%
data
# Out:
#         Country                      GDP_USD  \
# Year
# 2000  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2001  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2002  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2003  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2004  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2005  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2006  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2007  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2008  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2009  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2010  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2011  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2012  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2013  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2014  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2015  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2016  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2017  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2018  Palestine  Axes(0.125,0.11;0.775x0.77)
# 2019  Palestine  Axes(0.125,0.11;0.775x0.77)
# ...

# %%
data = data.set_index('Year')

# %%
data.head()
# Out:
#         Country       GDP_USD Population  growth_rate  fertility_rate  \
# Year
# 2000  Palestine  4.56 billion  33,74,000         5.33            5.36
# 2001  Palestine  4.59 billion  34,00,000       -50.00            5.22
# 2002  Palestine  4.34 billion  34,21,000       -46.30            5.07
# 2003  Palestine  3.56 billion  36,93,000       -16.10            5.15
# 2004  Palestine  3.89 billion  37,91,000        10.50            4.95
#
#       Infant Mortality Rate (per 1,000 live births)  \
# Year
# 2000                                           24.6
# 2001                                           22.5
# 2002                                           20.2
# 2003                                           23.0
# 2004                                           21.6
#
#       Maternal Mortality Rate (per 100,000 live births) agricultural_output  \
# Year
# 2000                                               26.0         880 million
# ...

# %%
data.Population
# Out:
# Year
# 2000    33,74,000
# 2001    34,00,000
# 2002    34,21,000
# 2003    36,93,000
# 2004    37,91,000
# 2005    38,90,000
# 2006    37,62,000
# 2007    38,65,000
# 2008    39,66,000
# 2009    40,18,000
# 2010    40,70,000
# 2011    41,98,000
# 2012    42,97,000
# 2013    44,04,000
# 2014    45,30,000
# 2015    46,92,000
# 2016    47,68,000
# 2017    48,16,000
# 2018    48,57,000
# 2019    48,95,000
# 2020    49,34,000
# 2021    53,68,000
# Name: Population, dtype: object

# %%
data.GDP_USD
# Out:
# Year
# 2000     4.56 billion
# 2001     4.59 billion
# 2002     4.34 billion
# 2003     3.56 billion
# 2004     3.89 billion
# 2005     4.13 billion
# 2006     4.47 billion
# 2007     4.96 billion
# 2008     5.05 billion
# 2009     4.98 billion
# 2010     4.95 billion
# 2011     5.39 billion
# 2012     5.65 billion
# 2013     5.69 billion
# 2014     5.71 billion
# 2015     5.87 billion
# 2016     5.93 billion
# 2017     6.00 billion
# 2018     6.10 billion
# 2019     6.09 billion
# 2020     6.20 billion
# 2021    15.05 billion
# Name: GDP_USD, dtype: object

# %%
for i in ['GDP_USD']:
    data[i] = data[i].apply(lambda x:float(x.split(' ')[0])*1000000000)

# %%
data
# Out:
#         Country       GDP_USD Population  growth_rate  fertility_rate  \
# Year
# 2000  Palestine  4.560000e+09  33,74,000         5.33            5.36
# 2001  Palestine  4.590000e+09  34,00,000       -50.00            5.22
# 2002  Palestine  4.340000e+09  34,21,000       -46.30            5.07
# 2003  Palestine  3.560000e+09  36,93,000       -16.10            5.15
# 2004  Palestine  3.890000e+09  37,91,000        10.50            4.95
# 2005  Palestine  4.130000e+09  38,90,000         7.60            4.78
# 2006  Palestine  4.470000e+09  37,62,000         5.80            4.14
# 2007  Palestine  4.960000e+09  38,65,000         5.30            4.07
# 2008  Palestine  5.050000e+09  39,66,000         4.20            3.98
# 2009  Palestine  4.980000e+09  40,18,000         6.80            4.00
# 2010  Palestine  4.950000e+09  40,70,000         8.50            3.99
# 2011  Palestine  5.390000e+09  41,98,000        -0.50            3.87
# ...

# %%
for i in ['agricultural_output']:
    data[i] = data[i].apply(lambda x:float(x.split(' ')[0])*1000000)

# %%
data
# Out:
#         Country       GDP_USD Population  growth_rate  fertility_rate  \
# Year
# 2000  Palestine  4.560000e+09  33,74,000         5.33            5.36
# 2001  Palestine  4.590000e+09  34,00,000       -50.00            5.22
# 2002  Palestine  4.340000e+09  34,21,000       -46.30            5.07
# 2003  Palestine  3.560000e+09  36,93,000       -16.10            5.15
# 2004  Palestine  3.890000e+09  37,91,000        10.50            4.95
# 2005  Palestine  4.130000e+09  38,90,000         7.60            4.78
# 2006  Palestine  4.470000e+09  37,62,000         5.80            4.14
# 2007  Palestine  4.960000e+09  38,65,000         5.30            4.07
# 2008  Palestine  5.050000e+09  39,66,000         4.20            3.98
# 2009  Palestine  4.980000e+09  40,18,000         6.80            4.00
# 2010  Palestine  4.950000e+09  40,70,000         8.50            3.99
# 2011  Palestine  5.390000e+09  41,98,000        -0.50            3.87
# ...

# %%
data = data.drop(['IT_output'] ,axis = 1)

# %%
data
# Out:
#         Country       GDP_USD Population  growth_rate  fertility_rate  \
# Year
# 2000  Palestine  4.560000e+09  33,74,000         5.33            5.36
# 2001  Palestine  4.590000e+09  34,00,000       -50.00            5.22
# 2002  Palestine  4.340000e+09  34,21,000       -46.30            5.07
# 2003  Palestine  3.560000e+09  36,93,000       -16.10            5.15
# 2004  Palestine  3.890000e+09  37,91,000        10.50            4.95
# 2005  Palestine  4.130000e+09  38,90,000         7.60            4.78
# 2006  Palestine  4.470000e+09  37,62,000         5.80            4.14
# 2007  Palestine  4.960000e+09  38,65,000         5.30            4.07
# 2008  Palestine  5.050000e+09  39,66,000         4.20            3.98
# 2009  Palestine  4.980000e+09  40,18,000         6.80            4.00
# 2010  Palestine  4.950000e+09  40,70,000         8.50            3.99
# 2011  Palestine  5.390000e+09  41,98,000        -0.50            3.87
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 2000 to 2021
# Data columns (total 14 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country                                            22 non-null     object
#  1   GDP_USD                                            22 non-null     float64
#  2   Population                                         22 non-null     object
#  3   growth_rate                                        22 non-null     float64
#  4   fertility_rate                                     22 non-null     float64
#  5   Infant Mortality Rate (per 1,000 live births)      22 non-null     float64
#  6   Maternal Mortality Rate (per 100,000 live births)  22 non-null     float64
#  7   agricultural_output                                22 non-null     float64
# ...

# %%
for i in ['Population']:
    data[i] = data[i].str.replace(',','')
    data[i] = data[i].astype('float')

# %%
data
# Out:
#         Country       GDP_USD  Population  growth_rate  fertility_rate  \
# Year
# 2000  Palestine  4.560000e+09   3374000.0         5.33            5.36
# 2001  Palestine  4.590000e+09   3400000.0       -50.00            5.22
# 2002  Palestine  4.340000e+09   3421000.0       -46.30            5.07
# 2003  Palestine  3.560000e+09   3693000.0       -16.10            5.15
# 2004  Palestine  3.890000e+09   3791000.0        10.50            4.95
# 2005  Palestine  4.130000e+09   3890000.0         7.60            4.78
# 2006  Palestine  4.470000e+09   3762000.0         5.80            4.14
# 2007  Palestine  4.960000e+09   3865000.0         5.30            4.07
# 2008  Palestine  5.050000e+09   3966000.0         4.20            3.98
# 2009  Palestine  4.980000e+09   4018000.0         6.80            4.00
# 2010  Palestine  4.950000e+09   4070000.0         8.50            3.99
# 2011  Palestine  5.390000e+09   4198000.0        -0.50            3.87
# ...

# %%
data.columns
# Out:
# Index(['Country', 'GDP_USD', 'Population', 'growth_rate', 'fertility_rate',
#        'Infant Mortality Rate (per 1,000 live births)',
#        'Maternal Mortality Rate (per 100,000 live births)',
#        'agricultural_output', 'Active Military Personnel',
#        'Reserve Military Personnel', 'literacy_rate', 'Number of Tanks',
#        'Number of Submarines', 'Number of Armoured Vehicles'],
#       dtype='object')

# %%
    data['GDP_USD'] = data['GDP_USD'].plot(kind = 'line')
    plt.title('GDP_USD')
    plt.show()

# %%
data['literacy_rate'] = data['literacy_rate'].plot(kind = 'line')
plt.title('literacy_rate')
plt.tight_layout()
plt.show()

# %%
data['Population'] = data['Population'].plot(kind = 'line')
plt.title('Population')
plt.grid()
plt.tight_layout()
plt.show()

# %%
data['fertiltiy_rate'] = data['fertility_rate'].plot(kind = 'line')
plt.title('fertility_rate')
plt.grid()
plt.tight_layout()
plt.show()

# %%
data['agricultural_output'] = data['agricultural_output'].plot(kind = 'line')
plt.title('agricultural_output')
plt.grid()
plt.tight_layout()
plt.show()

# %%
data.skew()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9044\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# growth_rate                                         -2.336697
# fertility_rate                                       0.792479
# Infant Mortality Rate (per 1,000 live births)        0.542960
# Maternal Mortality Rate (per 100,000 live births)    0.559614
# Active Military Personnel                            0.000000
# Reserve Military Personnel                           0.000000
# Number of Tanks                                      0.000000
# Number of Submarines                                 0.000000
# Number of Armoured Vehicles                          0.000000
# dtype: float64

# %%
data.kurtosis()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9044\2361870383.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurtosis()
# growth_rate                                          4.910460
# fertility_rate                                      -0.772481
# Infant Mortality Rate (per 1,000 live births)       -0.975968
# Maternal Mortality Rate (per 100,000 live births)   -0.392377
# Active Military Personnel                            0.000000
# Reserve Military Personnel                           0.000000
# Number of Tanks                                      0.000000
# Number of Submarines                                 0.000000
# Number of Armoured Vehicles                          0.000000
# dtype: float64

# %%
## growth_rate variable is called as leptokuric kurtosis bcz of it is greater than 3
